# %%
import ROOT
import PlotTools
from ROOT import TFile, TCanvas, kRed, THStack, kYellow, kGreen, kBlack, TLegend, TH1F, TH2F
ROOT.enableJSVis()
import matplotlib.pyplot as plt
import matplotlib.path as mpath
import numpy as np
import matplotlib.patches as mpatches
# Out:
# Welcome to JupyROOT 6.18/00

# %%
deltabs = [0.0, 0.25, 0.5, 0.75, 1.0]
nom = [1.182284442,0.919821624,0.562336479,0.355370182,0.19377206]
err = [0.009151236,0.007014799,0.004106174,0.002561773,0.001748039]
acc_up = [1.226940585,0.953237608,0.582013295,0.366331684,0.199503248]
acc_up_err = [0.009151236,0.007014799,0.004106174,0.002561773,0.001748039]
acc_down = [1.13762836,0.886405648,0.54265966,0.34440868,0.188040874]
acc_down_err = [0.009151236,0.007014799,0.004106174,0.002561773,0.001748039]

# %%
plt.figure()
kwargs = dict(capsize=2,
              elinewidth=1.1, linewidth=0.6, ms=7)
plt.errorbar(deltabs, nom, yerr=err,fmt='bo',**kwargs, label = 'Nominal')
#plt.errorbar(deltabs,acc_up, yerr=acc_up_err,fmt='r^',**kwargs, label = 'Scale Up')
#plt.errorbar(deltabs,acc_down, yerr=acc_down_err,fmt='gs',**kwargs, label = 'Scale Down')
plt.title('m = 500 GeV, gb=1.0')
plt.xlabel('delta bs', fontsize=12)
plt.ylabel('Acceptance(%)', fontsize=12)
plt.grid(True)
#plt.legend(loc='best', frameon=True)
plt.savefig('../plots/acceptance_deltabs.png')
plt.show()

# %%
mass = [350,500,650,800,950]
nom2 = [0.949400731,1.18228444,1.14489914,1.221896602,1.15834425]
err2 = [0.003355047,0.009151236,0.016443212,0.027680061,0.040948345]
acc_up2 = [0.983630595,1.226940585,1.191086296,1.273051561,1.208014915]
acc_up_err2 = [0.003355047,0.009151236,0.016443212,0.027680061,0.040948345]
acc_down2 = [0.915170863,1.13762836,1.098711983,1.170741623,1.108673579]
acc_down_err2 = [0.003355047,0.009151236,0.016443212,0.027680061,0.040948345]

# %%
plt.figure()
kwargs = dict(capsize=2,
              elinewidth=1.1, linewidth=0.6, ms=7)
plt.errorbar(mass, nom2, yerr=err2,fmt='bo',**kwargs, label = 'Nominal')
plt.errorbar(mass,acc_up2, yerr=acc_up_err2,fmt='r^',**kwargs, label = 'Scale Up')
plt.errorbar(mass,acc_down2, yerr=acc_down_err2,fmt='gs',**kwargs, label = 'Scale Down')
plt.title('delta_bs = 0, gb = 1')
plt.xlabel('Mass [GeV] ', fontsize=12)
plt.ylabel('Acceptance(%)', fontsize=12)
plt.grid(True)
plt.legend(loc='best', frameon=True)
plt.savefig('../plots/alphaUnc_mass.png')
plt.show()
